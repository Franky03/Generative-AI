# %%
import transformers
from transformers import pipeline, AutoTokenizer

# %%
def initialize_summarizer(language="english"):
    models = {
        "english": "facebook/bart-large-cnn",
        "portuguese": "neuralmind/bert-base-portuguese-cased"
    }
    return pipeline("summarization", model=models[language], tokenizer=models[language])

# %%
def get_text_and_summary_lengths():
    text = input("Enter the text to be summarized: ")

    max_length = int(input("Enter the maximum length for the summary: "))
    min_length = int(input("Enter the minimum length for the summary: "))

    return text, max_length, min_length

def display_summary(summary):
  print("\nSummary:")
  print(summary)

# %%
def main():
    language = input("Which language do you want to use? (english/portuguese): ").lower()
    summarizer = initialize_summarizer(language)

    while True:
        text, max_length, min_length = get_text_and_summary_lengths()
        summary = summarizer(text, max_length=max_length, min_length=min_length)

        display_summary(summary[0]['summary_text'])

        cont = input("\nDo you want to summarize another text? (yes/no) ").lower()
        if cont != "yes":
            break

# %%
main()
# Out:
# Which language do you want to use? (english/portuguese): english
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Enter the text to be summarized: The details of Miyamoto Musashi's early life are difficult to verify. Musashi himself simply states in The Book of Five Rings that he was born in Harima Province.[5] Niten Ki (an early biography of Musashi) supports the assertion that Musashi was born in 1584: "[He] was born in Banshū, in Tenshō 12 [1584], the Year of the Monkey."[6] The historian Kamiko Tadashi, commenting on Musashi's text, notes: "Munisai was Musashi's father ... he lived in Miyamoto village, in the Yoshino district [of Mimasaka Province]. Musashi was most probably born here."
# Enter the maximum length for the summary: 50
# Enter the minimum length for the summary: 40
#
# Summary:
# The details of Miyamoto Musashi's early life are difficult to verify. Musashi himself states in The Book of Five Rings that he was born in Harima Province. Niten Ki (an early biography of Musashi) supports the
#
# Do you want to summarize another text? (yes/no) yes
# Enter the text to be summarized: The details of Miyamoto Musashi's early life are difficult to verify. Musashi himself simply states in The Book of Five Rings that he was born in Harima Province.[5] Niten Ki (an early biography of Musashi) supports the assertion that Musashi was born in 1584: "[He] was born in Banshū, in Tenshō 12 [1584], the Year of the Monkey."[6] The historian Kamiko Tadashi, commenting on Musashi's text, notes: "Munisai was Musashi's father ... he lived in Miyamoto village, in the Yoshino district [of Mimasaka Province]. Musashi was most probably born here.
# Enter the maximum length for the summary: 100
# Enter the minimum length for the summary: 80
#
# Summary:
# The details of Miyamoto Musashi's early life are difficult to verify. Musashi himself states in The Book of Five Rings that he was born in Harima Province. Niten Ki (an early biography of Musashi) supports the assertion that Musashi wasborn in 1584. The historian Kamiko Tadashi, commenting on Musashi's text, notes that his father, Munisai, lived in Miyamoto village, Mimasaka Province.
#
# Do you want to summarize another text? (yes/no) no
