# %%
import transformers
from transformers import pipeline

# %%
def initialize_mask_filling(model_name="bert-base-uncased"):
  return pipeline("fill-mask", model=model_name)

top_k = 5

def get_sentence():
  sentence = input(f"Enter sentence (please [MASK] where you want the mask): ")
  if "[MASK]" not in sentence:
    print("Warning: You didn't provide a [MASK]. Adding one at the end.")
    sentence += " [MASK]"


  return sentence

def display_result(results):
  for item in results:
    print("Score: {:<20} Token: {:<10} Token String: {:<10} Sequence: {}".format(
            item['score'],
            item['token'],
            item['token_str'],
            item['sequence']
        ))

# %%
def main():
  mask_filler = initialize_mask_filling()

  sentences = get_sentence()
  result = mask_filler(sentences, top_k=top_k)

  display_result(result)

# %%
main()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Enter sentence (please [MASK] where you want the mask): Brazil is the [MASK] country in the world
# Score: 0.23774810135364532  Token: 10479      Token String: smallest   Sequence: brazil is the smallest country in the world
# Score: 0.18881140649318695  Token: 18429      Token String: richest    Sequence: brazil is the richest country in the world
# Score: 0.11944879591464996  Token: 2922       Token String: largest    Sequence: brazil is the largest country in the world
# Score: 0.09961947798728943  Token: 6587       Token String: youngest   Sequence: brazil is the youngest country in the world
# Score: 0.05952262505888939  Token: 4587       Token String: oldest     Sequence: brazil is the oldest country in the world
